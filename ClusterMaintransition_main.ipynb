# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# !pip install mpi4py
# Out:
# ...
#      |████████████████████████████████| 2.5 MB 5.0 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#   Created wheel for mpi4py: filename=mpi4py-3.1.3-cp37-cp37m-linux_x86_64.whl size=2185297 sha256=4bb9a11d4e04830bdd3d76fbb4cce28d84638efa2f1b231ec5430208b46f8fa8
#   Stored in directory: /root/.cache/pip/wheels/7a/07/14/6a0c63fa2c6e473c6edc40985b7d89f05c61ff25ee7f0ad9ac
# Successfully built mpi4py
# ...

# %%
! mpiexec --allow-run-as-root -np 8 python3 /content/drive/MyDrive/研究/WiFiLog/ClusterMainTransition.py
# Out:
#          AP  ...  floor
# 0  Bldg1AP1  ...    2.0
# 1  Bldg1AP2  ...    2.0
# 2  Bldg1AP3  ...    3.0
# 3  Bldg1AP4  ...    3.0
# 4  Bldg1AP5  ...    4.0
#
# [5 rows x 4 columns]
# Cluster 2
#          AP  ...  floor
# 0  Bldg1AP1  ...    2.0
# 1  Bldg1AP2  ...    2.0
# 2  Bldg1AP3  ...    3.0
# 3  Bldg1AP4  ...    3.0
# 4  Bldg1AP5  ...    4.0
#
# [5 rows x 4 columns]
# Cluster 2
#          AP  ...  floor
# 0  Bldg1AP1  ...    2.0
# 1  Bldg1AP2  ...    2.0
# 2  Bldg1AP3  ...    3.0
# 3  Bldg1AP4  ...    3.0
# 4  Bldg1AP5  ...    4.0
#
# [5 rows x 4 columns]
# Cluster 2
#          AP  ...  floor
# 0  Bldg1AP1  ...    2.0
# 1  Bldg1AP2  ...    2.0
# 2  Bldg1AP3  ...    3.0
# 3  Bldg1AP4  ...    3.0
# 4  Bldg1AP5  ...    4.0
#
# [5 rows x 4 columns]
# Cluster 2
#          AP  ...  floor
# 0  Bldg1AP1  ...    2.0
# 1  Bldg1AP2  ...    2.0
# 2  Bldg1AP3  ...    3.0
# 3  Bldg1AP4  ...    3.0
# 4  Bldg1AP5  ...    4.0
#
# [5 rows x 4 columns]
# Cluster 2
#          AP  ...  floor
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/drive/MyDrive/研究/WiFiLog/wifidata/pre/201407.csv')
df
# Out:
#                    timestamp                                    client    AP
# 0        2014-07-01 00:00:00  f64443953de139ed7f06f8499de48d892d9d1a9c   605
# 1        2014-07-01 00:00:03  a3a70736a03d6e74599d334d5f7a81ee84d0ffdd  1021
# 2        2014-07-01 00:00:05  b83a4f6bca9b6df3993fa49903c34eaa76fbc8b5   327
# 3        2014-07-01 00:00:10  e46ebcb72cdedbe6daa4de7ddac1252ff4d946db   199
# 4        2014-07-01 00:00:11  a4c3999bb38fb833672dc9f0b7213e1e9b80e473   199
# ...                      ...                                       ...   ...
# 1426685  2014-07-31 23:58:56  a36cef2cdfe6dbe4536ed19a547dda5c910f7b76  1054
# 1426686  2014-07-31 23:59:14  3236567d56e24a04b2e1e782d81057d1450ccf52   605
# 1426687  2014-07-31 23:59:18  24edebce2cdd7660413a09fde42033cb12c11bb9  1094
# 1426688  2014-07-31 23:59:26  6100af5f702d09d55a218d12cac0da5bf936b9a4   767
# 1426689  2014-07-31 23:59:27  d46f2088521f1e60b4c7ff36e9ef066f9a2c7366   298
#
# [1426690 rows x 3 columns]

# %%
user = pd.read_csv('/content/drive/MyDrive/研究/WiFiLog/wifidata/cluster/201407/concat_201407_3h.csv')
user_list = user[user['kmeans']==4]['client'].tolist()
df[df['client'].isin(user_list)]
# Out:
#                    timestamp                                    client   AP
# 231      2014-07-01 00:24:41  1a014abf027cab8c17c2d3c5d52e52a4183410e1  919
# 243      2014-07-01 00:25:36  1a014abf027cab8c17c2d3c5d52e52a4183410e1  920
# 272      2014-07-01 00:28:52  1a014abf027cab8c17c2d3c5d52e52a4183410e1  919
# 343      2014-07-01 00:36:35  804c6110509067847c211e5b80490369e9ba12c8  240
# 554      2014-07-01 00:59:22  1a014abf027cab8c17c2d3c5d52e52a4183410e1  919
# ...                      ...                                       ...  ...
# 1424689  2014-07-31 20:23:35  1a014abf027cab8c17c2d3c5d52e52a4183410e1  918
# 1424692  2014-07-31 20:23:43  1a014abf027cab8c17c2d3c5d52e52a4183410e1  917
# 1424693  2014-07-31 20:23:45  1a014abf027cab8c17c2d3c5d52e52a4183410e1  936
# 1424707  2014-07-31 20:24:49  1a014abf027cab8c17c2d3c5d52e52a4183410e1  916
# 1424709  2014-07-31 20:24:58  1a014abf027cab8c17c2d3c5d52e52a4183410e1  894
#
# [3142 rows x 3 columns]
